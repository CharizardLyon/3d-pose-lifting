# %%
import pandas as pd

# %%
df = pd.read_hdf(
    "C:/Users/Chari/OneDrive/Escritorio/DATA/Monocular3d/raw_test/session_rangel_izq/pose-2d/camE.h5"
)

# Print the DataFrame
print(df)
# Out:
# scorer      Mediapipe                                                 \
# bodyparts       WRIST                          THUMB_CMC
# coords              x           y likelihood           x           y
# 0          343.299370  317.651968   0.846430  329.000473  318.252497
# 1          347.549362  322.541571   0.960420  323.705139  323.416758
# 2          343.920441  326.387587   0.957438  320.771370  330.437851
# 3          339.975662  330.026836   0.959493  316.527920  335.188465
# 4          341.953926  329.552536   0.960949  318.763504  336.312275
# ...               ...         ...        ...         ...         ...
# 2111       384.097824  319.272423   0.925024  365.996323  321.304893
# 2112       394.207916  318.745451   0.880583  371.146927  320.946264
# 2113       389.439240  320.481663   0.890022  367.396927  322.743931
# 2114       386.663513  323.031464   0.956154  359.848747  322.938824
# 2115       391.188278  317.562017   0.981761  359.684982  325.020990
#
# ...
